# %%
import pickle
import numpy as np
import re
from utils import clean

# %%
with open ("all_nba_from_oct17", 'rb') as fp:
    doc_set = pickle.load(fp)
docs = list(doc_set)

# %%
clean(docs[91])
# Out:
# ['new',
#  'orleans',
#  'pelicans',
#  'trailing',
#  'phoenix',
#  'suns',
#  'points',
#  'early',
#  'second',
#  'quarter',
#  'jrue',
#  'holiday',
#  'found',
#  'darius',
#  'miller',
#  'running',
#  'free',
#  'perimeter',
#  'kicking',
#  'sharpshooter',
#  'ball',
#  'rest',
#  'teammates',
#  'watched',
#  'ball',
#  'clang',
#  'rim',
#  'painted',
#  'area',
#  'containing',
#  'four',
#  'suns',
#  'players',
#  'one',
#  'problem',
#  'suns',
#  'anthony',
#  'davis',
#  'also',
#  'occupied',
#  'paint',
#  'davis',
#  'boxed',
#  'dragan',
#  'bender',
#  'collected',
#  'rebound',
#  'left',
#  'hand',
#  'gathered',
#  'rose',
#  'brawny',
#  'finish',
#  'drawing',
#  'contact',
#  'completing',
#  'play',
#  'one',
#  'eight',
#  'offensive',
#  'rebounds',
#  'pelicans',
#  'team',
#  'notable',
#  'statistic',
#  'paled',
#  'comparison',
#  'final',
#  'buzzer',
#  'sounded',
#  'new',
#  'orleans',
#  'smoothie',
#  'king',
#  'center',
#  'cementing',
# ...

# %%
tokens

# %%
import nltk
nltk.download('punkt')

# %%
# docs[2]
docs[80]

# %%
s = " he can\'t wa"
s.replace("\\'", "'")

# %%
docs = [clean_string(doc).split() for doc in docs]

# %%
docs[:2]

# %%
from gensim.models import Word2Vec

# %%
s = "me. 🔥\n\nThe"

# %%
# def clean_and_split_article(a):
#     punctuation = '''!()[]{};:'"\,<>/?@#$%^&*_~'''
#     replacements = [("&amp;", "and"),
#                     ("—", " "), ("p.m.", "pm"), ("a.m.", "am"), (".", " ")]
#     removals = ["\xa0"]
    
#     for old, new in replacements:
#         a = a.replace(old, new)
    
#     for char in punctuation:
#         a = a.replace(char, "")
    
#     for s in removals:
#         a = a.replace(s, "")
    
#     bad_starters = ("https")
#     bad_enders = (".com")
    
    
#     lower_case = [split_on_caps(w).strip().lower() for w in a.split()
#                     if not w.startswith(bad_starters) and not w.endswith(bad_enders)]
    
#     # remove numbers

# %%
# first_and_last_names = []
# for name in TOP_100_PLAYERS:
#     first, last = name.split()
#     first_and_last_names.append(first)
#     first_and_last_names.append(last)
